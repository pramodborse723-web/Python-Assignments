# %% [markdown]
# # Python Basics and Data types

# %% [markdown]
# # 1. Variable manipulation

# %%
student_name = 'Shambhavi'
age = 20
GPA = 8
subjects = 'Science, Math, English, Social Sciences'

# %%
student_name
# Out:
# 'Shambhavi'

# %%
age     # age in years
# Out:
# 20

# %%
GPA
# Out:
# 8

# %%
subjects
# Out:
# 'Science, Math, English, Social Sciences'

# %%
age_in_months = age * 12     # age in months

# %%
age_in_months
# Out:
# 240

# %%
print("Student " + student_name + " of age " + str(age) + " years, " + "has scored " + str(GPA) + " GPA with subjects " + subjects + ".")
# Out:
# Student Shambhavi of age 20 years, has scored 8 GPA with subjects Science, Math, English, Social Sciences.

# %% [markdown]
# # 2. Type Conversion

# %%
x = 6.3483    # float data type

# %%
int(x)        # typecastng to integer
# Out:
# 6

# %%
print('After typecasting float to integer the decimal part is dropped and a complete number is returned.')
# Out:
# After typecasting float to integer the decimal part is dropped and a complete number is returned.
